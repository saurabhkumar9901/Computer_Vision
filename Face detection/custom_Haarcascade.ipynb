# %% [markdown]
# ## Downloading Positive images
# To create dataset XML file we require positive images i.e. object we want to predict and negative images i.e. images except for the object we want to predict

# %%
from icrawler.builtin import BingImageCrawler

#we are building cats image detection that's why we put cat here
#if you want some other images then put that name in classes list
classes=['cats images'] 
number=100
#here root directory is find your root directory there u will find 
#new file name data in which all images are saved.
for c in classes:
    bing_crawler=BingImageCrawler(storage={'root_dir':f'p/{c.replace(" ",".")}'})
    bing_crawler.crawl(keyword=c,filters=None,max_num=number,offset=0)
# Out:
# 2024-11-16 13:41:20,958 - INFO - icrawler.crawler - start crawling...
# 2024-11-16 13:41:20,973 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2024-11-16 13:41:20,975 - INFO - feeder - thread feeder-001 exit
# 2024-11-16 13:41:20,979 - INFO - icrawler.crawler - starting 1 parser threads...
# 2024-11-16 13:41:20,982 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2024-11-16 13:41:21,783 - INFO - parser - parsing result page https://www.bing.com/images/async?q=cats images&first=0
# 2024-11-16 13:41:22,628 - INFO - downloader - image #1	http://getwallpapers.com/wallpaper/full/d/1/e/1129346-cute-cats-wallpaper-1080x1920-full-hd.jpg
# 2024-11-16 13:41:23,960 - INFO - downloader - image #2	https://upload.wikimedia.org/wikipedia/commons/a/a5/Red_Kitten_01.jpg
# 2024-11-16 13:41:24,111 - ERROR - downloader - Response status code 403, file https://wallpapershome.com/images/wallpapers/kitten-2160x3840-cat-cute-8k-14575.jpg
# ...

# %% [markdown]
# ## Downloading Negetive images
# To collect negative images we are using the same command but using n as a folder after root directory (check line no 10 in both the codes )

# %%
from icrawler.builtin import BingImageCrawler         
classes=['trees','roads','Human faces']
number=100
for c in classes:
    bing_crawler=BingImageCrawler(storage={'root_dir':f'n/{c.replace(" ",".")}'}) #//see n is represent negaive images 
    bing_crawler.crawl(keyword=c,filters=None,max_num=number,offset=0)
# Out:
# 2024-11-16 13:47:04,941 - INFO - icrawler.crawler - start crawling...
# 2024-11-16 13:47:04,942 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2024-11-16 13:47:04,944 - INFO - feeder - thread feeder-001 exit
# 2024-11-16 13:47:04,947 - INFO - icrawler.crawler - starting 1 parser threads...
# 2024-11-16 13:47:04,949 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2024-11-16 13:47:05,498 - INFO - parser - parsing result page https://www.bing.com/images/async?q=trees&first=0
# 2024-11-16 13:47:05,615 - INFO - downloader - image #1	https://www.thespruce.com/thmb/T0tNK2-pITvMEPYOhsKLa0sTTwk=/2102x0/filters:no_upscale():max_bytes(150000):strip_icc()/sugar-maple-trees-in-fall-1037004188-a7a5ad50aa6449f199700a9d57cd2d80.jpg
# 2024-11-16 13:47:06,832 - INFO - downloader - image #2	https://wallpaperaccess.com/full/1543668.jpg
# 2024-11-16 13:47:08,179 - INFO - downloader - image #3	https://wallpaperaccess.com/full/3350078.jpg
# ...

# %% [markdown]
# ## To train object detection classifier follow following simple steps
#
# 1. Goto start->search for (Cascade-Trainer-GUI)->open it
# 2. create a new directory on Desktop lets say named temp and create a new folder inside it named p to copy the positive images we download previously to this folder. refer to the following image.
# 3.  create a new folder named it with n in the temp folder and copy-paste negative images we download previously.
# 4. when all done open the folder temp on desktop you will se two folders named n and p like this.
# 5. open the cascade trainer GUI paste the previously copied path into sample folder location also count the no of negative images you have and put it in negative image count. Example : C:/Users/245970/Desktop/temp
# 6. Count the number of negetive images and put in the "Negetive Image count"
# 7. Click on the common section this will open a new page in the same window. Select no of stages carefully try to put it low if you put it so high then it will take a long time to train.but also maybe it will inc accuracy.
# My suggestion is that try to put no of stages= 15 and click on the button start on the right bottom corner.
#
# 8.  Then go back to temp folder you will see a new file named classifier open that folder you will find a new file named cascade.xml copy path to this file

# %%
#here is code to check the output
import cv2
face_cascade=cv2.CascadeClassifier(r"C:\Users\245970\Desktop\temp\classifier\cascade.xml")###path of cascade file
## following is an test image u can take any image from the p folder in the temp folder and paste address of it on below line 
img= cv2.imread(r"D:\Computer Vision Masterclass\p\cats.images\000003.jpg")###path of image file which we want to detect
resized = cv2.resize(img,(400,200))
gray=cv2.cvtColor(resized,cv2.COLOR_BGR2GRAY)
faces=face_cascade.detectMultiScale(gray,scaleFactor=1.7, minNeighbors=8, minSize=(96, 96))#try to tune this 6.5 and 17 parameter to get good result 
##if not getting good result try to train new cascade.xml file again deleting other file expect p and n in temp folder
for(x,y,w,h) in faces:
    print(w, h)
    resized=cv2.rectangle(resized,(x,y),(x+w,y+h),(0,255,0),2)
cv2.imshow('img',resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 118 118
